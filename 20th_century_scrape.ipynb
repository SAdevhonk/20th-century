# %%
# Install required libraries from requirements.txt
# %pip install -r requirements.txt
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Verify required package versions (must match the exercise requirements)
from importlib.metadata import version

print("pandas==", version("pandas"))
print("requests==", version("requests"))
print("beautifulsoup4==", version("beautifulsoup4"))
print("selenium==", version("selenium"))
print("webdriver-manager==", version("webdriver-manager"))
print("matplotlib==", version("matplotlib"))
# Out:
# pandas== 1.5.1
# requests== 2.28.1
# beautifulsoup4== 4.11.1
# selenium== 3.141.0
# webdriver-manager== 3.8.5
# matplotlib== 3.6.2

# %%
# Scrape full page text from Wikipedia and save as .txt file

from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from pathlib import Path

# Path to local ChromeDriver
driver_path = Path("drivers/chromedriver-mac-arm64/chromedriver")

if not driver_path.exists():
    raise FileNotFoundError(f"ChromeDriver not found at: {driver_path}")

# Configure Chrome options
options = Options()
options.add_argument("--headless")
options.add_argument("--no-sandbox")
options.add_argument("--disable-dev-shm-usage")

# Start browser
driver = webdriver.Chrome(executable_path=str(driver_path), options=options)

# Open Wikipedia page
url = "https://en.wikipedia.org/wiki/Key_events_of_the_20th_century"
driver.get(url)

# Extract full visible page text
page_text = driver.find_element(By.TAG_NAME, "body").text

# Close browser
driver.quit()

# Save to file
output_file = "20th_century_key_events.txt"
with open(output_file, "w", encoding="utf-8") as f:
    f.write(page_text)

print("Saved successfully.")
print("Characters saved:", len(page_text))
# Out:
# Saved successfully.
# Characters saved: 110314
